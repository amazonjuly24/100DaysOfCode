# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data=pd.read_csv("/home/manjula/python/house/housedata.csv")
data.head()
#data.describe()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of bedrooms')
plt.xlabel('bedroom')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.jointplot(x=data.lat.values, y=data.long.values, size=15)
plt.xlabel('latitude')
plt.ylabel('longitude')
sns.despine
# Out:
# /home/manjula/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price, data.sqft_living)
plt.title("Price vs square feet")
# Out:
# Text(0.5,1,'Price vs square feet')

# %%
plt.scatter(data.price, data.long)
plt.title("Price vs location/longitude")
# Out:
# Text(0.5,1,'Price vs location')

# %%
plt.scatter(data.price, data.lat)
plt.title("Price vs location/latitude")
# Out:
# Text(0.5,1,'Price vs location/latitude')

# %%
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

# %%
plt.scatter(data.waterfront,data.price)

# %%
data1=data.drop(['id','price'],axis=1)
data1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.floors.value_counts().plot(kind='bar')

# %%
plt.scatter(data.floors,data.price)

# %%
plt.scatter(data.condition,data.price)

# %%
plt.scatter(data.zipcode,data.price)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
data['price']
# Out:
# 0         221900.0
# 1         538000.0
# 2         180000.0
# 3         604000.0
# 4         510000.0
# 5        1225000.0
# 6         257500.0
# 7         291850.0
# 8         229500.0
# 9         323000.0
# 10        662500.0
# 11        468000.0
# 12        310000.0
# 13        400000.0
# 14        530000.0
# 15        650000.0
# 16        395000.0
# 17        485000.0
# 18        189000.0
# 19        230000.0
# 20        385000.0
# 21       2000000.0
# 22        285000.0
# 23        252700.0
# 24        329000.0
# 25        233000.0
# 26        937000.0
# 27        667000.0
# 28        438000.0
# 29        719000.0
#            ...
# 21583     399950.0
# 21584     380000.0
# 21585     270000.0
# 21586     505000.0
# 21587     385000.0
# 21588     414500.0
# 21589     347500.0
# 21590    1222500.0
# 21591     572000.0
# 21592     475000.0
# 21593    1088000.0
# 21594     350000.0
# 21595     520000.0
# 21596     679950.0
# 21597    1575000.0
# 21598     541800.0
# ...

# %%
labels=data['price']
#dates=[1 if values==2014 else 0 for values in data.date]
#data['date']=dates
train1=data.drop(['id','date','price'],axis=1)

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
# Out:
# 0.7320342760357734

# %%
from sklearn import ensemble
clf=ensemble.GradientBoostingRegressor(n_estimators=400, max_depth=5,min_samples_split=2,learning_rate=0.1,loss='ls')

# %%
clf.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=5, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=400, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
clf.score(x_test,y_test)
# Out:
# 0.9205535057091137

# %%
#tpc=np.zeros((params['n_estimators']),dtype=np.float64)
#Do correction

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
pca=PCA()

# %%
pca.fit_transform(scale(train1))
# Out:
# array([[-2.64785461e+00, -4.54699955e-02, -3.16665762e-01, ...,
#         -5.10795532e-01, -7.94687728e-02, -3.12538616e-13],
#        [-2.34485164e-01,  1.68297114e+00, -7.61521725e-01, ...,
#          1.84904915e-01,  9.81487761e-01,  4.79290433e-13],
#        [-2.57007792e+00, -6.14344122e-01,  3.49292423e-01, ...,
#          1.42985411e+00, -1.38570764e-01, -1.95179093e-13],
#        ...,
#        [-2.41985641e+00, -1.10027662e+00, -1.46293798e+00, ...,
#         -6.96757428e-01,  9.66785881e-01, -3.92698195e-18],
#        [ 3.32183025e-01, -1.88043103e+00, -1.04412760e+00, ...,
#         -4.28979100e-01, -3.97449542e-01,  4.85147065e-17],
#        [-2.43180432e+00, -1.08505981e+00, -1.47248379e+00, ...,
#         -6.96427916e-01,  9.53674385e-01, -3.34129586e-18]])
